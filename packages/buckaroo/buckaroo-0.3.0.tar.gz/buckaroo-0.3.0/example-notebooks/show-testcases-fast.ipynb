# %%
import pandas as pd
import numpy as np
import json
from buckaroo.buckaroo_widget import BuckarooWidget, disable, enable
import matplotlib
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
df = pd.read_parquet('banklist.parquet')
bw = BuckarooWidget(df)
bw
# Out:
# BuckarooWidget(commandConfig={'argspecs': {'dropcol': [None], 'to_datetime': [None], 'safeint': [None], 'filln…

# %%
df2 = pd.read_csv('death-by-suicide-hispanic.csv')
#bw = BuckarooWidget(df2)
df2
# Out:
# BuckarooWidget(commandConfig={'argspecs': {'dropcol': [None], 'to_datetime': [None], 'safeint': [None], 'filln…

# %%
df3 = pd.read_parquet('Covid-data.gzip.parquet')
df3
# Out:
# BuckarooWidget(commandConfig={'argspecs': {'dropcol': [None], 'to_datetime': [None], 'safeint': [None], 'filln…

# %%
df4 = pd.read_csv('WPP2022_Demographic_Indicators_Medium.csv')
df4
# Out:
# /var/folders/th/jfr8ccjx09g2j_18ty_t3xnh0000gn/T/ipykernel_9429/413833355.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4 = pd.read_csv('WPP2022_Demographic_Indicators_Medium.csv')
# /Users/paddy/buckaroo/buckaroo/summary_stats.py:184: FutureWarning: reindexing with a non-unique Index is deprecated and will raise in a future version.
#   sdf.loc['is_duplicate':, duplicate_cols] = -5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/envs/buckaroo-dev/lib/python3.11/site-packages/IPython/core/formatters.py:917, in IPythonDisplayFormatter.__call__(self, obj)
#     915     pass
#     916 else:
# --> 917     printer(obj)
#     918     return True
#     919 # Finally look for special method names
#
# File ~/buckaroo/buckaroo/buckaroo_widget.py:182, in _display_as_buckaroo(df)
#     181 def _display_as_buckaroo(df):
# --> 182     return display(BuckarooWidget(df, showCommands=False, showTransformed=False))
#
# File ~/buckaroo/buckaroo/buckaroo_widget.py:110, in BuckarooWidget.__init__(self, df, sampled, summaryStats, reorderdColumns, showTransformed, showCommands, really_reorder_columns)
#     101 def __init__(self, df,
#     102              sampled=True,
#     103              summaryStats=False,
#    (...)
#     106              showCommands=True,
#     107              really_reorder_columns=False):
#     108     super().__init__()
# --> 110     self.stats = DfStats(df)
#     111     self.summaryDf = df_to_obj(self.stats.sdf, self.stats.col_order)
#     113     self.dfConfig.update(dict(
#     114         totalRows=len(df),
#     115         columns=len(df.columns),
#     116         showTransformed=showTransformed,
#     117         showCommands=showCommands))
#
# File ~/buckaroo/buckaroo/summary_stats.py:232, in DfStats.__init__(self, df, summary_func, order_col_func)
#     230 self.sdf = summary_func(df)
#     231 self.cpd = get_cor_pair_dict(self.df, self.sdf)
# --> 232 self.col_order = order_col_func(self.sdf, self.cpd)
#
# File ~/buckaroo/buckaroo/summary_stats.py:184, in order_columns(summary_stats_df, corr_pair_dict)
#     181 first_cols, duplicate_cols = order_groupings(groupings, duplicate_col_rankings)
#     183 sdf.loc['first_col':, first_cols] = 5
# --> 184 sdf.loc['is_duplicate':, duplicate_cols] = -5
#     186 col_scores = sdf.loc[['one_distinct', 'first_col', 'datetime_score', 'is_duplicate']].sum()
#     187 return col_scores.sort_values().index.values[::-1]
#
# File ~/opt/anaconda3/envs/buckaroo-dev/lib/python3.11/site-packages/pandas/core/indexing.py:814, in _LocationIndexer.__setitem__(self, key, value)
#     812 else:
#     813     key = com.apply_if_callable(key, self.obj)
# --> 814 indexer = self._get_setitem_indexer(key)
#     815 self._has_valid_setitem_indexer(key)
#     817 iloc = self if self.name == "iloc" else self.obj.iloc
#
# File ~/opt/anaconda3/envs/buckaroo-dev/lib/python3.11/site-packages/pandas/core/indexing.py:678, in _LocationIndexer._get_setitem_indexer(self, key)
#     673 """
#     674 Convert a potentially-label-based key into a positional indexer.
#     675 """
#     676 if self.name == "loc":
#     677     # always holds here bc iloc overrides _get_setitem_indexer
# --> 678     self._ensure_listlike_indexer(key)
#     680 if isinstance(key, tuple):
#     681     for x in key:
#
# File ~/opt/anaconda3/envs/buckaroo-dev/lib/python3.11/site-packages/pandas/core/indexing.py:804, in _LocationIndexer._ensure_listlike_indexer(self, key, axis, value)
#     794 if (
#     795     axis == column_axis
#     796     and not isinstance(self.obj.columns, MultiIndex)
#    (...)
#     800 ):
#     801     # GH#38148
#     802     keys = self.obj.columns.union(key, sort=False)
# --> 804     self.obj._mgr = self.obj._mgr.reindex_axis(keys, axis=0, only_slice=True)
#
# File ~/opt/anaconda3/envs/buckaroo-dev/lib/python3.11/site-packages/pandas/core/internals/base.py:100, in DataManager.reindex_axis(self, new_index, axis, fill_value, only_slice)
#      95 """
#      96 Conform data manager to new index.
#      97 """
#      98 new_index, indexer = self.axes[axis].reindex(new_index)
# --> 100 return self.reindex_indexer(
#     101     new_index,
#     102     indexer,
#     103     axis=axis,
#     104     fill_value=fill_value,
#     105     copy=False,
#     106     only_slice=only_slice,
#     107 )
#
# File ~/opt/anaconda3/envs/buckaroo-dev/lib/python3.11/site-packages/pandas/core/internals/managers.py:737, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     735 # some axes don't allow reindexing with dups
#     736 if not allow_dups:
# --> 737     self.axes[axis]._validate_can_reindex(indexer)
#     739 if axis >= self.ndim:
#     740     raise IndexError("Requested axis not found in manager")
#
# File ~/opt/anaconda3/envs/buckaroo-dev/lib/python3.11/site-packages/pandas/core/indexes/base.py:4316, in Index._validate_can_reindex(self, indexer)
#    4314 # trying to reindex on an axis with duplicates
#    4315 if not self._index_as_unique and len(indexer):
# -> 4316     raise ValueError("cannot reindex on an axis with duplicate labels")
#
# ValueError: cannot reindex on an axis with duplicate labels
#        SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 0              1    900   NaN       NaN       NaN        1.0          1
# 1              1    900   NaN       NaN       NaN        1.0          1
# 2              1    900   NaN       NaN       NaN        1.0          1
# 3              1    900   NaN       NaN       NaN        1.0          1
# 4              1    900   NaN       NaN       NaN        1.0          1
# ...          ...    ...   ...       ...       ...        ...        ...
# 43467        290    876   2.0       WLF        WF      876.0          4
# 43468        290    876   2.0       WLF        WF      876.0          4
# 43469        290    876   2.0       WLF        WF      876.0          4
# 43470        290    876   2.0       WLF        WF      876.0          4
# 43471        290    876   2.0       WLF        WF      876.0          4
#
#         LocTypeName  ParentID                   Location  ...  Q0060Male  \
# 0             World         0                      World  ...   580.7496
# 1             World         0                      World  ...   566.7283
# 2             World         0                      World  ...   546.3173
# 3             World         0                      World  ...   535.8289
# 4             World         0                      World  ...   523.1236
# ...             ...       ...                        ...  ...        ...
# 43467  Country/Area       957  Wallis and Futuna Islands  ...    23.1199
# 43468  Country/Area       957  Wallis and Futuna Islands  ...    22.7966
# 43469  Country/Area       957  Wallis and Futuna Islands  ...    22.4732
# 43470  Country/Area       957  Wallis and Futuna Islands  ...    22.1497
# 43471  Country/Area       957  Wallis and Futuna Islands  ...        NaN
#
#       Q0060Female     Q1550  Q1550Male  Q1550Female     Q1560  Q1560Male  \
# 0        498.0396  240.3164   271.6253     208.1916  378.6968   430.2594
# 1        490.1993  231.1772   258.0905     203.7797  368.3186   415.8362
# 2        477.2639  218.6745   240.0344     197.1422  353.0546   395.5327
# 3        469.5325  212.8720   232.6019     193.0492  345.0826   385.8433
# 4        458.4842  205.7622   224.0498     187.4439  335.4420   374.6576
# ...           ...       ...        ...          ...       ...        ...
# 43467     28.0450    7.5105     6.3613       8.6783   21.0197    20.2116
# 43468     27.4133    7.3642     6.2703       8.4752   20.6236    19.9248
# 43469     26.9919    7.2513     6.1793       8.3398   20.3113    19.6379
# 43470     26.6620    7.1535     6.0883       8.2346   20.0363    19.3509
# 43471         NaN       NaN        NaN          NaN       NaN        NaN
#
#        Q1560Female  NetMigrations   CNMR
# 0         324.9308           0.00  0.000
# 1         319.3364           0.00  0.000
# 2         309.9103           0.00  0.000
# 3         303.9053           0.00  0.000
# 4         295.9944           0.00  0.000
# ...            ...            ...    ...
# 43467      21.8411          -0.01 -0.995
# 43468      21.3338          -0.01 -1.000
# 43469      20.9955          -0.01 -1.005
# 43470      20.7325          -0.01 -1.011
# 43471          NaN            NaN    NaN
#
# [43472 rows x 67 columns]

# %%
df5 = pd.read_parquet('2014-01-citibike-trip-data.parquet')
df5

# %%
df6 =  pd.read_parquet('1993-flights.gzip.parquet')
df6[:10_000]

# %%
df8 = pd.read_csv('train_extended.csv')
df8.loc[0,'Length'] = 1.111
df8.loc[1,'Length'] = 8.888
df8

# %%
df9 = pd.read_csv('scorecard.csv')
bw = BuckarooWidget(df9)

# %%
df10 = pd.read_csv('Machine_readable_file_bd_employ.csv')
bw = BuckarooWidget(df10)

# %%
# %timeit bw = BuckarooWidget(df6)
